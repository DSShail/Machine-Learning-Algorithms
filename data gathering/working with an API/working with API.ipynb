# %%
import pandas as pd
import requests

# %%
requests.get('')

# %% [markdown]
# #### consuming movie api using requests.get()

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5OGY0ODg1NGYxYTVkMThiYjJlZGNjZGYyZTZhMzg0YiIsInN1YiI6IjY1OTFiYjUzMDI4ZjE0Nzc0NWM1YTY0NCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.3o4FaT5EfGAZb9_UA8UPfDQFEIumCPYoPAIKegRavGc"
}

response = requests.get(url, headers=headers)
response_json=response.json()

results=response_json['results']

# %% [markdown]
# #### converting the json results into a dataframe

# %%
df=pd.DataFrame(results)[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     140.141
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     142.932
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      78.574
# 3  The true story of how businessman Oskar Schind...   1993-12-15      72.135
# 4  The defense and the prosecution have rested an...   1957-04-10      72.611
#
#    vote_average  vote_count
# 0         8.711       25393
# 1         8.707       19335
# 2         8.592       11665
# 3         8.572       15026
# 4         8.545        7965

# %%
# Out:
# (20, 7)

# %%
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,456):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI5OGY0ODg1NGYxYTVkMThiYjJlZGNjZGYyZTZhMzg0YiIsInN1YiI6IjY1OTFiYjUzMDI4ZjE0Nzc0NWM1YTY0NCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.3o4FaT5EfGAZb9_UA8UPfDQFEIumCPYoPAIKegRavGc"
    }
    response = requests.get(url, headers=headers)
    response_json=response.json()
    results=response_json['results']
    temp_df=pd.DataFrame(results)[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    print(temp_df.head())
    df1=pd.concat([df1,temp_df],ignore_index=True)
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     140.141
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     142.932
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      78.574
# 3  The true story of how businessman Oskar Schind...   1993-12-15      72.135
# 4  The defense and the prosecution have rested an...   1957-04-10      72.611
#
#    vote_average  vote_count
# 0         8.711       25393
# 1         8.707       19335
# 2         8.592       11665
# 3         8.572       15026
# 4         8.545        7965
#        id                                  title  \
# 0     550                             Fight Club
# ...

# %%
df1.shape
# Out:
# (9100, 7)

# %%
pd.to_csv('movies.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pd.to_csv('movies.csv')
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %%
df1.to_csv('movies.csv')
